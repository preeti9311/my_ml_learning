#        -3.58585859, -3.68686869, -3.78787879, -3.88888889, -3.98989899,
#        -4.09090909, -4.19191919, -4.29292929, -4.39393939, -4.49494949,
#        -4.5959596 , -4.6969697 , -4.7979798 , -4.8989899 , -5.        ])

# %%
x1=np.linspace(-5.0,5.0,100)
y1=np.sqrt(5**2-x1**2)
y1=np.hstack([y1,-y1])
x1=np.hstack([x1,-x1])

# %%
plt.scatter(y,x)
plt.scatter(y1,x1)

# %%
import pandas as pd
df1=pd.DataFrame(np.vstack([y,x]).T,columns=['X1','X2'])
df1['Y']=0
df2=pd.DataFrame(np.vstack([y1,x1]).T,columns=['X1','X2'])
df2['Y']=1
df = pd.concat([df1, df2])
df.head(5)
# Out:
#          X1       X2  Y
# 0  8.660254 -5.00000  0
# 1  8.717792 -4.89899  0
# 2  8.773790 -4.79798  0
# 3  8.828277 -4.69697  0
# 4  8.881281 -4.59596  0

# %%
### independent and dependent features
x=df.iloc[:,:2]
y=df.Y

# %%
df.tail()
# Out:
#            X1       X2  Y
# 195 -1.969049 -4.59596  1
# 196 -1.714198 -4.69697  1
# 197 -1.406908 -4.79798  1
# 198 -0.999949 -4.89899  1
# 199 -0.000000 -5.00000  1

# %%
## split the dataset into train and test

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train
# Out:
#            X1        X2
# 47   4.993619 -0.252525
# 110 -9.169553  3.989899
# 16   9.410082 -3.383838
# 66   9.860133  1.666667
# 153 -9.993749 -0.353535
# ..        ...       ...
# 71   9.761334  2.171717
# 106 -8.982945  4.393939
# 70   4.551063  2.070707
# 148 -4.997704  0.151515
# 102 -8.773790  4.797980
#
# [300 rows x 2 columns]

# %%
df['X1_Square']=df['X1']**2
df['X2_Square']=df['X2']**2
df['X1*X2']=(df['X1']*df['X2'])
df.head()
# Out:
#          X1       X2  Y  X1_Square  X2_Square      X1*X2
# 0  8.660254 -5.00000  0  75.000000  25.000000 -43.301270
# 1  8.717792 -4.89899  0  75.999898  24.000102 -42.708375
# 2  8.773790 -4.79798  0  76.979390  23.020610 -42.096467
# 3  8.828277 -4.69697  0  77.938476  22.061524 -41.466150
# 4  8.881281 -4.59596  0  78.877155  21.122845 -40.818009

# %%
x=df[['X1','X2','X1_Square','X2_Square','X1*X2']]
y=df['Y']

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 195    1
# 196    1
# 197    1
# 198    1
# 199    1
# Name: Y, Length: 400, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
import plotly.express as px

# %%
pip install notebook plotly nbformat ipython
# Out:
# Collecting notebook
#   Downloading notebook-7.5.5-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: plotly in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (6.6.0)
# Requirement already satisfied: nbformat in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (5.10.4)
# Requirement already satisfied: ipython in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (9.12.0)
# Collecting jupyter-server<3,>=2.4.0 (from notebook)
#   Using cached jupyter_server-2.17.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyterlab-server<3,>=2.28.0 (from notebook)
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab<4.6,>=4.5.6 (from notebook)
#   Downloading jupyterlab-4.5.6-py3-none-any.whl.metadata (16 kB)
# Collecting notebook-shim<0.3,>=0.2 (from notebook)
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\preet\appdata\roaming\python\python312\site-packages (from notebook) (6.5.4)
# Collecting anyio>=3.1.0 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->notebook)
#   Using cached argon2_cffi-25.1.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting jinja2>=3.0.3 (from jupyter-server<3,>=2.4.0->notebook)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\preet\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\preet\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.9.1)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->notebook)
#   Using cached jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading jupyter_server_terminals-0.5.4-py3-none-any.whl.metadata (5.9 kB)
# Collecting nbconvert>=6.4.4 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading nbconvert-7.17.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: packaging>=22.0 in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.0)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading prometheus_client-0.24.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting pywinpty>=2.0.1 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading pywinpty-3.0.3-cp312-cp312-win_amd64.whl.metadata (5.9 kB)
# Requirement already satisfied: pyzmq>=24 in c:\users\preet\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook) (27.1.0)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading send2trash-2.1.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->notebook)
#   Using cached terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\preet\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Collecting websocket-client>=1.7 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading websocket_client-1.9.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting async-lru>=1.0.0 (from jupyterlab<4.6,>=4.5.6->notebook)
#   Downloading async_lru-2.3.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting httpx<1,>=0.25.0 (from jupyterlab<4.6,>=4.5.6->notebook)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in c:\users\preet\appdata\roaming\python\python312\site-packages (from jupyterlab<4.6,>=4.5.6->notebook) (7.2.0)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<4.6,>=4.5.6->notebook)
#   Using cached jupyter_lsp-2.3.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (from jupyterlab<4.6,>=4.5.6->notebook) (80.9.0)
# Collecting certifi (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.6->notebook)
#   Using cached certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.6->notebook)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.6->notebook)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.6->notebook)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.28.0->notebook)
#   Downloading babel-2.18.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.28.0->notebook)
#   Downloading json5-0.13.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (4.26.0)
# Collecting requests>=2.31 (from jupyterlab-server<3,>=2.28.0->notebook)
#   Downloading requests-2.33.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (from plotly) (2.18.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\users\preet\appdata\roaming\python\python312\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\preet\appdata\roaming\python\python312\site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\preet\appdata\roaming\python\python312\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\users\preet\appdata\roaming\python\python312\site-packages (from ipython) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\preet\appdata\roaming\python\python312\site-packages (from ipython) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (from ipython) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\preet\appdata\roaming\python\python312\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\preet\appdata\roaming\python\python312\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.6.0)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (4.15.0)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook)
#   Using cached argon2_cffi_bindings-25.1.0-cp39-abi3-win_amd64.whl.metadata (7.5 kB)
# Requirement already satisfied: comm>=0.1.1 in c:\users\preet\appdata\roaming\python\python312\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\preet\appdata\roaming\python\python312\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (1.8.20)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\preet\appdata\roaming\python\python312\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (7.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\preet\appdata\roaming\python\python312\site-packages (from jedi>=0.18.2->ipython) (0.8.6)
# Collecting MarkupSafe>=2.0 (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook)
#   Using cached markupsafe-3.0.3-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.30.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\preet\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.9.4)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading python_json_logger-4.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting pyyaml>=5.3 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Using cached pyyaml-6.0.3-cp312-cp312-win_amd64.whl.metadata (2.4 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting rfc3987-syntax>=1.1.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Using cached rfc3987_syntax-1.1.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading webcolors-25.10.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting beautifulsoup4 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading bleach-6.3.0-py3-none-any.whl.metadata (31 kB)
# Collecting defusedxml (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading mistune-3.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting nbclient>=0.5.0 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading nbclient-0.10.4-py3-none-any.whl.metadata (8.3 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting webencodings (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting tinycss2<1.5,>=1.1.0 (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Using cached tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: six>=1.5 in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook)
#   Downloading charset_normalizer-3.4.6-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting urllib3<3,>=1.26 (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting lark>=1.2.2 (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading lark-1.3.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: executing>=1.2.0 in c:\users\preet\appdata\roaming\python\python312\site-packages (from stack_data>=0.6.0->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\preet\appdata\roaming\python\python312\site-packages (from stack_data>=0.6.0->ipython) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\preet\appdata\roaming\python\python312\site-packages (from stack_data>=0.6.0->ipython) (0.2.3)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook)
#   Using cached cffi-2.0.0-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook)
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading arrow-1.4.0-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: tzdata in c:\users\preet\anaconda3\envs\practise_env\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (2025.3)
# Downloading notebook-7.5.5-py3-none-any.whl (14.6 MB)
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/14.6 MB 10.1 MB/s eta 0:00:02
#    ------------ --------------------------- 4.7/14.6 MB 11.9 MB/s eta 0:00:01
#    ------------------------- -------------- 9.2/14.6 MB 15.0 MB/s eta 0:00:01
#    -------------------------------------- - 14.2/14.6 MB 17.1 MB/s eta 0:00:01
#    ---------------------------------------- 14.6/14.6 MB 15.8 MB/s  0:00:00
# Using cached jupyter_server-2.17.0-py3-none-any.whl (388 kB)
# Downloading jupyterlab-4.5.6-py3-none-any.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ------------------- -------------------- 6.0/12.4 MB 30.7 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.4 MB 33.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 28.9 MB/s  0:00:00
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
# Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Downloading anyio-4.13.0-py3-none-any.whl (114 kB)
# Using cached argon2_cffi-25.1.0-py3-none-any.whl (14 kB)
# Downloading async_lru-2.3.0-py3-none-any.whl (8.4 kB)
# Downloading babel-2.18.0-py3-none-any.whl (10.2 MB)
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    -------------------- ------------------- 5.2/10.2 MB 29.0 MB/s eta 0:00:01
#    ---------------------------------------- 10.2/10.2 MB 26.5 MB/s  0:00:00
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading json5-0.13.0-py3-none-any.whl (36 kB)
# Using cached jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Downloading jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Using cached jupyter_lsp-2.3.0-py3-none-any.whl (76 kB)
# Downloading jupyter_server_terminals-0.5.4-py3-none-any.whl (13 kB)
# Using cached markupsafe-3.0.3-cp312-cp312-win_amd64.whl (15 kB)
# Downloading nbconvert-7.17.0-py3-none-any.whl (261 kB)
# Downloading mistune-3.2.0-py3-none-any.whl (53 kB)
# Downloading bleach-6.3.0-py3-none-any.whl (164 kB)
# Using cached tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Downloading nbclient-0.10.4-py3-none-any.whl (25 kB)
# Using cached pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading prometheus_client-0.24.1-py3-none-any.whl (64 kB)
# Downloading python_json_logger-4.0.0-py3-none-any.whl (15 kB)
# Downloading pywinpty-3.0.3-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 29.9 MB/s  0:00:00
# Using cached pyyaml-6.0.3-cp312-cp312-win_amd64.whl (154 kB)
# Downloading requests-2.33.0-py3-none-any.whl (65 kB)
# Downloading charset_normalizer-3.4.6-cp312-cp312-win_amd64.whl (154 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Using cached rfc3987_syntax-1.1.0-py3-none-any.whl (8.0 kB)
# Downloading lark-1.3.1-py3-none-any.whl (113 kB)
# Downloading send2trash-2.1.0-py3-none-any.whl (17 kB)
# Using cached terminado-0.18.1-py3-none-any.whl (14 kB)
# Downloading webcolors-25.10.0-py3-none-any.whl (14 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Using cached argon2_cffi_bindings-25.1.0-cp39-abi3-win_amd64.whl (31 kB)
# Using cached cffi-2.0.0-cp312-cp312-win_amd64.whl (183 kB)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.4.0-py3-none-any.whl (68 kB)
# Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
# Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webencodings, websocket-client, webcolors, urllib3, uri-template, tinycss2, soupsieve, send2trash, rfc3986-validator, rfc3339-validator, pyyaml, pywinpty, python-json-logger, pycparser, prometheus-client, pandocfilters, mistune, MarkupSafe, lark, jupyterlab-pygments, jsonpointer, json5, idna, h11, fqdn, defusedxml, charset_normalizer, certifi, bleach, babel, async-lru, terminado, rfc3987-syntax, requests, jinja2, httpcore, cffi, beautifulsoup4, arrow, anyio, jupyter-server-terminals, isoduration, httpx, argon2-cffi-bindings, argon2-cffi, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook
#
#     ---------------------------------------  1/54 [websocket-client]
#     ---------------------------------------  1/54 [websocket-client]
#    -- -------------------------------------  3/54 [urllib3]
#    -- -------------------------------------  3/54 [urllib3]
#    -- -------------------------------------  3/54 [urllib3]
#    --- ------------------------------------  5/54 [tinycss2]
#    ---- -----------------------------------  6/54 [soupsieve]
#    ----- ----------------------------------  7/54 [send2trash]
#    ------- -------------------------------- 10/54 [pyyaml]
#    ------- -------------------------------- 10/54 [pyyaml]
#    -------- ------------------------------- 11/54 [pywinpty]
#    --------- ------------------------------ 13/54 [pycparser]
#    ---------- ----------------------------- 14/54 [prometheus-client]
#    ---------- ----------------------------- 14/54 [prometheus-client]
#    ---------- ----------------------------- 14/54 [prometheus-client]
#    ----------- ---------------------------- 16/54 [mistune]
#    ----------- ---------------------------- 16/54 [mistune]
#    ------------ --------------------------- 17/54 [MarkupSafe]
#    ------------- -------------------------- 18/54 [lark]
#    ------------- -------------------------- 18/54 [lark]
#    ------------- -------------------------- 18/54 [lark]
#    -------------- ------------------------- 20/54 [jsonpointer]
#    ---------------- ----------------------- 22/54 [idna]
#    ---------------- ----------------------- 22/54 [idna]
#    ----------------- ---------------------- 24/54 [fqdn]
#    ------------------- -------------------- 26/54 [charset_normalizer]
#    -------------------- ------------------- 27/54 [certifi]
#    -------------------- ------------------- 28/54 [bleach]
#    -------------------- ------------------- 28/54 [bleach]
#    -------------------- ------------------- 28/54 [bleach]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    --------------------- ------------------ 29/54 [babel]
#    ---------------------- ----------------- 31/54 [terminado]
#    ------------------------ --------------- 33/54 [requests]
#    ------------------------ --------------- 33/54 [requests]
#    ------------------------ --------------- 33/54 [requests]
#    ------------------------- -------------- 34/54 [jinja2]
#    ------------------------- -------------- 34/54 [jinja2]
#    ------------------------- -------------- 34/54 [jinja2]
#    ------------------------- -------------- 35/54 [httpcore]
#    ------------------------- -------------- 35/54 [httpcore]
#    -------------------------- ------------- 36/54 [cffi]
#    -------------------------- ------------- 36/54 [cffi]
#    --------------------------- ------------ 37/54 [beautifulsoup4]
#    --------------------------- ------------ 37/54 [beautifulsoup4]
#    ---------------------------- ----------- 38/54 [arrow]
#    ---------------------------- ----------- 39/54 [anyio]
#    ---------------------------- ----------- 39/54 [anyio]
#    ---------------------------- ----------- 39/54 [anyio]
#    ------------------------------ --------- 41/54 [isoduration]
#    ------------------------------- -------- 42/54 [httpx]
#    ------------------------------- -------- 42/54 [httpx]
#    -------------------------------- ------- 44/54 [argon2-cffi]
#    ---------------------------------- ----- 46/54 [jupyter-events]
#    ---------------------------------- ----- 47/54 [nbconvert]
#    ---------------------------------- ----- 47/54 [nbconvert]
#    ---------------------------------- ----- 47/54 [nbconvert]
#    ---------------------------------- ----- 47/54 [nbconvert]
#    ----------------------------------- ---- 48/54 [jupyter-server]
#    ----------------------------------- ---- 48/54 [jupyter-server]
#    ----------------------------------- ---- 48/54 [jupyter-server]
#    ----------------------------------- ---- 48/54 [jupyter-server]
#    ----------------------------------- ---- 48/54 [jupyter-server]
#    ----------------------------------- ---- 48/54 [jupyter-server]
#    ------------------------------------ --- 49/54 [notebook-shim]
#    ------------------------------------- -- 50/54 [jupyterlab-server]
#    ------------------------------------- -- 50/54 [jupyterlab-server]
#    ------------------------------------- -- 51/54 [jupyter-lsp]
#    ------------------------------------- -- 51/54 [jupyter-lsp]
#    -------------------------------------- - 52/54 [jupyterlab]
#    -------------------------------------- - 52/54 [jupyterlab]
#    -------------------------------------- - 52/54 [jupyterlab]
#    -------------------------------------- - 52/54 [jupyterlab]
#    -------------------------------------- - 52/54 [jupyterlab]
#    -------------------------------------- - 52/54 [jupyterlab]
#    -------------------------------------- - 52/54 [jupyterlab]
#    -------------------------------------- - 52/54 [jupyterlab]
#    -------------------------------------- - 52/54 [jupyterlab]
#    -------------------------------------- - 52/54 [jupyterlab]
#    -------------------------------------- - 52/54 [jupyterlab]
#    -------------------------------------- - 52/54 [jupyterlab]
#    -------------------------------------- - 52/54 [jupyterlab]
#    -------------------------------------- - 52/54 [jupyterlab]
#    -------------------------------------- - 52/54 [jupyterlab]
#    -------------------------------------- - 52/54 [jupyterlab]
#    -------------------------------------- - 52/54 [jupyterlab]
#    ---------------------------------------  53/54 [notebook]
#    ---------------------------------------  53/54 [notebook]
#    ---------------------------------------  53/54 [notebook]
#    ---------------------------------------  53/54 [notebook]
#    ---------------------------------------  53/54 [notebook]
#    ---------------------------------------  53/54 [notebook]
#    ---------------------------------------  53/54 [notebook]
#    ---------------------------------------  53/54 [notebook]
#    ---------------------------------------  53/54 [notebook]
#    ---------------------------------------- 54/54 [notebook]
#
# Successfully installed MarkupSafe-3.0.3 anyio-4.13.0 argon2-cffi-25.1.0 argon2-cffi-bindings-25.1.0 arrow-1.4.0 async-lru-2.3.0 babel-2.18.0 beautifulsoup4-4.14.3 bleach-6.3.0 certifi-2026.2.25 cffi-2.0.0 charset_normalizer-3.4.6 defusedxml-0.7.1 fqdn-1.5.1 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 isoduration-20.11.0 jinja2-3.1.6 json5-0.13.0 jsonpointer-3.1.1 jupyter-events-0.12.0 jupyter-lsp-2.3.0 jupyter-server-2.17.0 jupyter-server-terminals-0.5.4 jupyterlab-4.5.6 jupyterlab-pygments-0.3.0 jupyterlab-server-2.28.0 lark-1.3.1 mistune-3.2.0 nbclient-0.10.4 nbconvert-7.17.0 notebook-7.5.5 notebook-shim-0.2.4 pandocfilters-1.5.1 prometheus-client-0.24.1 pycparser-3.0 python-json-logger-4.0.0 pywinpty-3.0.3 pyyaml-6.0.3 requests-2.33.0 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rfc3987-syntax-1.1.0 send2trash-2.1.0 soupsieve-2.8.3 terminado-0.18.1 tinycss2-1.4.0 uri-template-1.3.0 urllib3-2.6.3 webcolors-25.10.0 webencodings-0.5.1 websocket-client-1.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
fig=px.scatter_3d(df,x='X1',y='X2',z='X1*X2',color='Y')
import plotly.io as pio
pio.renderers.default = 'browser'
fig.show()

# %%
fig=px.scatter_3d(df,x='X1_Square',y='X2_Square',z='X1*X2',color='Y')
import plotly.io as pio
pio.renderers.default = 'browser'
fig.show()

# %%
from sklearn.svm import  SVC
from sklearn.metrics import accuracy_score
classifier=SVC(kernel='linear')
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from sklearn.svm import  SVC
from sklearn.metrics import accuracy_score
classifier=SVC(kernel='poly')
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from sklearn.svm import  SVC
from sklearn.metrics import accuracy_score
classifier=SVC(kernel='rbf')
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from sklearn.svm import  SVC
from sklearn.metrics import accuracy_score
classifier=SVC(kernel='sigmoid')
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 1.0
