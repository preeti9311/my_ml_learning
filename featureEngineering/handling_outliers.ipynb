# %%
### minimum,maximum,median,Q1,Q3,IQR

import numpy as np

# %%
lst_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]
print("max_marks:",np.max(lst_marks))
print("min_marks:",np.min(lst_marks))
minimum,Q1,median,Q3,maximum=np.quantile(lst_marks,[0,0.25,0.50,0.75,1])
# Out:
# max_marks: 99
# min_marks: 32

# %%
minimum,Q1,median,Q3,maximum
# Out:
# (np.float64(32.0),
#  np.float64(54.0),
#  np.float64(67.0),
#  np.float64(89.0),
#  np.float64(99.0))

# %%
IQR=Q3-Q1
print("IQR",IQR)
# Out:
# IQR 35.0

# %%
lower_fence=Q1-1.5*IQR
upper_fence=Q3+1.5*IQR
print("lower_fence:",lower_fence)
print("upper_fence:",upper_fence)
# Out:
# lower_fence: 1.5
# upper_fence: 141.5

# %%
outliers=[x for x in lst_marks if x<lower_fence or x>upper_fence]
print(outliers)
# Out:
# []

# %%
import seaborn as sns
sns.boxplot(lst_marks)
# Out:
# <Axes: >
